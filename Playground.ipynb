# %%
from langchain_chroma import Chroma
from langchain.indexes import SQLRecordManager, index
import os
import glob

# %%
from utils.extract_knowledge import extract_text_from_pdf, split_text_into_chunks

# %%
def get_records_manager(database, namespace):

    # if the file exists, load the record manager from the file
    if os.path.exists(database):
        record_manager = SQLRecordManager(
            namespace, db_url=f"sqlite:///{database}"
        )
        return record_manager
    else:
        record_manager = SQLRecordManager(
            namespace, db_url=f"sqlite:///{database}"
        )
        record_manager.create_schema()

def get_huggingface_model(model_name):
    from langchain_community.embeddings import HuggingFaceEmbeddings
    model_kwargs =  {'device': 'cpu'}
    encode_kwargs = {'normalize_embeddings': False}
    hf = HuggingFaceEmbeddings(
        model_name=model_name,
        model_kwargs=model_kwargs,
        encode_kwargs=encode_kwargs
    )
    return hf
    

if not os.path.exists("./.cache"):
    os.makedirs("./.cache")

namespace = f"rags/docs"

model_name = "BAAI/bge-base-en-v1.5"
print(f"Loading Hugging Face model {model_name}")
hf = get_huggingface_model(model_name)

print(f"Getting records manager for namespace {namespace} in db")
record_manager = get_records_manager("./.cache/record_manager_cache.sql", namespace)


chroma = Chroma("docs",  embedding_function=hf, persist_directory="./.cache/chroma/docs")

docs = extract_text_from_pdf("data/unilever.pdf")
docs = split_text_into_chunks(docs)

print(f"Indexing {len(docs)} splits of Ollama docs")

# %%
indexing = index(
    docs,
    record_manager,
    chroma,
    cleanup='incremental',
    source_id_key="key",
)
print(indexing)

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="microsoft/Phi-3-mini-128k-instruct", trust_remote_code=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Use a pipeline as a high-level helper
# ----> 2 from transformers import pipeline
#       4 pipe = pipeline("text-generation", model="microsoft/Phi-3-mini-128k-instruct", trust_remote_code=True)
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/miniconda/lib/python3.10/site-packages/transformers/utils/import_utils.py:1542, in _LazyModule.__getattr__(self, name)
#    1540     value = self._get_module(name)
#    1541 elif name in self._class_to_module.keys():
# -> 1542     module = self._get_module(self._class_to_module[name])
#    1543     value = getattr(module, name)
#    1544 else:
#
# File ~/miniconda/lib/python3.10/site-packages/transformers/utils/import_utils.py:1552, in _LazyModule._get_module(self, module_name)
#    1550 def _get_module(self, module_name: str):
#    1551     try:
# -> 1552         return importlib.import_module("." + module_name, self.__name__)
#    1553     except Exception as e:
#    1554         raise RuntimeError(
#    1555             f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1556             f" traceback):\n{e}"
#    1557         ) from e
#
# File ~/miniconda/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/miniconda/lib/python3.10/site-packages/transformers/pipelines/__init__.py:63
#      61 from .conversational import Conversation, ConversationalPipeline
#      62 from .depth_estimation import DepthEstimationPipeline
# ---> 63 from .document_question_answering import DocumentQuestionAnsweringPipeline
#      64 from .feature_extraction import FeatureExtractionPipeline
#      65 from .fill_mask import FillMaskPipeline
#
# File ~/miniconda/lib/python3.10/site-packages/transformers/pipelines/document_question_answering.py:29
#      20 from ..utils import (
#      21     ExplicitEnum,
#      22     add_end_docstrings,
#    (...)
#      26     logging,
#      27 )
#      28 from .base import ChunkPipeline, build_pipeline_init_args
# ---> 29 from .question_answering import select_starts_ends
#      32 if is_vision_available():
#      33     from PIL import Image
#
# File ~/miniconda/lib/python3.10/site-packages/transformers/pipelines/question_answering.py:9
#       5 from typing import TYPE_CHECKING, Dict, List, Optional, Tuple, Union
#       7 import numpy as np
# ----> 9 from ..data import SquadExample, SquadFeatures, squad_convert_examples_to_features
#      10 from ..modelcard import ModelCard
#      11 from ..tokenization_utils import PreTrainedTokenizer
#
# File ~/miniconda/lib/python3.10/site-packages/transformers/data/__init__.py:26
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .data_collator import (
#      16     DataCollatorForLanguageModeling,
#      17     DataCollatorForPermutationLanguageModeling,
#    (...)
#      24     default_data_collator,
#      25 )
# ---> 26 from .metrics import glue_compute_metrics, xnli_compute_metrics
#      27 from .processors import (
#      28     DataProcessor,
#      29     InputExample,
#    (...)
#      43     xnli_tasks_num_labels,
#      44 )
#
# File ~/miniconda/lib/python3.10/site-packages/transformers/data/metrics/__init__.py:19
#      15 from ...utils import is_sklearn_available, requires_backends
#      18 if is_sklearn_available():
# ---> 19     from scipy.stats import pearsonr, spearmanr
#      20     from sklearn.metrics import f1_score, matthews_corrcoef
#      23 DEPRECATION_WARNING = (
#      24     "This metric will be removed from the library soon, metrics should be handled with the 🤗 Evaluate "
#      25     "library. You can have a look at this example script for pointers: "
#      26     "https://github.com/huggingface/transformers/blob/main/examples/pytorch/text-classification/run_glue.py"
#      27 )
#
# File ~/miniconda/lib/python3.10/site-packages/scipy/stats/__init__.py:606
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     601
#     602 """  # noqa: E501
#     604 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     605                                DegenerateDataWarning, FitError)
# --> 606 from ._stats_py import *
#     607 from ._variation import variation
#     608 from .distributions import *
#
# File ~/miniconda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:49
#      47 import scipy.special as special
#      48 from scipy import linalg
# ---> 49 from . import distributions
#      50 from . import _mstats_basic as mstats_basic
#      51 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#      52                                    siegelslopes)
#
# File ~/miniconda/lib/python3.10/site-packages/scipy/stats/distributions.py:14
#      11 from . import _discrete_distns
#      13 from ._continuous_distns import *  # noqa: F403
# ---> 14 from ._levy_stable import levy_stable
#      15 from ._discrete_distns import *  # noqa: F403
#      16 from ._entropy import entropy
#
# File ~/miniconda/lib/python3.10/site-packages/scipy/stats/_levy_stable/__init__.py:17
#      15 from .._distn_infrastructure import rv_continuous, _ShapeInfo
#      16 from .._continuous_distns import uniform, expon, _norm_pdf, _norm_cdf
# ---> 17 from .levyst import Nolan
#      18 from scipy._lib.doccer import inherit_docstring_from
#      21 __all__ = ["levy_stable", "levy_stable_gen", "pdf_from_cf_with_fft"]
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1002, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:945, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1439, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1411, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1548, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:1591, in _fill_cache(self)
#
# KeyboardInterrupt:

# %%
docs = extract_text_from_pdf("./data/unilever.pdf")
len(docs[:50000])
# Out:
# 50000

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

torch.random.manual_seed(0)

model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-128k-instruct", 
    device_map="cuda", 
    torch_dtype="auto", 
    trust_remote_code=True, 
    attn_implementation="eager"
)
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-128k-instruct")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
generation_args = {
    "max_new_tokens": 500,
}
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
pipe(docs[:50000],**generation_args)
# Out:
# You are not running the flash-attention implementation, expect numerical differences.
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[5], line 9
#       1 generation_args = {
#       2     "max_new_tokens": 500,
#       3 }
#       4 pipe = pipeline(
#       5     "text-generation",
#       6     model=model,
#       7     tokenizer=tokenizer,
#       8 )
# ----> 9 pipe(docs[:50000],**generation_args)
#
# File ~/miniconda/lib/python3.10/site-packages/transformers/pipelines/text_generation.py:263, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     261         return super().__call__(chats, **kwargs)
#     262 else:
# --> 263     return super().__call__(text_inputs, **kwargs)
#
# File ~/miniconda/lib/python3.10/site-packages/transformers/pipelines/base.py:1243, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1235     return next(
#    1236         iter(
#    1237             self.get_iterator(
#    (...)
#    1240         )
#    1241     )
#    1242 else:
# -> 1243     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/miniconda/lib/python3.10/site-packages/transformers/pipelines/base.py:1250, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1248 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1249     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1250     model_outputs = self.forward(model_inputs, **forward_params)
#    1251     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1252     return outputs
#
# File ~/miniconda/lib/python3.10/site-packages/transformers/pipelines/base.py:1150, in Pipeline.forward(self, model_inputs, **forward_params)
#    1148     with inference_context():
#    1149         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1150         model_outputs = self._forward(model_inputs, **forward_params)
#    1151         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1152 else:
#
# File ~/miniconda/lib/python3.10/site-packages/transformers/pipelines/text_generation.py:350, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     347         generate_kwargs["min_length"] += prefix_length
#     349 # BS x SL
# --> 350 generated_sequence = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     351 out_b = generated_sequence.shape[0]
#     352 if self.framework == "pt":
#
# File ~/miniconda/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/miniconda/lib/python3.10/site-packages/transformers/generation/utils.py:1824, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1816     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1817         input_ids=input_ids,
#    1818         expand_size=generation_config.num_return_sequences,
#    1819         is_encoder_decoder=self.config.is_encoder_decoder,
#    1820         **model_kwargs,
#    1821     )
#    1823     # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 1824     result = self._sample(
#    1825         input_ids,
#    1826         logits_processor=prepared_logits_processor,
#    1827         logits_warper=prepared_logits_warper,
#    1828         stopping_criteria=prepared_stopping_criteria,
#    1829         generation_config=generation_config,
#    1830         synced_gpus=synced_gpus,
#    1831         streamer=streamer,
#    1832         **model_kwargs,
#    1833     )
#    1835 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    1836     # 11. prepare logits warper
#    1837     prepared_logits_warper = (
#    1838         self._get_logits_warper(generation_config) if generation_config.do_sample else None
#    1839     )
#
# File ~/miniconda/lib/python3.10/site-packages/transformers/generation/utils.py:2463, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2460 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2462 # forward pass to get next token
# -> 2463 outputs = self(
#    2464     **model_inputs,
#    2465     return_dict=True,
#    2466     output_attentions=output_attentions,
#    2467     output_hidden_states=output_hidden_states,
#    2468 )
#    2470 if synced_gpus and this_peer_finished:
#    2471     continue  # don't waste resources running the code we don't need
#
# File ~/miniconda/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/bbd531db4632bb631b0c44d98172894a0c594dd0/modeling_phi3.py:1286, in Phi3ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1283 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1285 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1286 outputs = self.model(
#    1287     input_ids=input_ids,
#    1288     attention_mask=attention_mask,
#    1289     position_ids=position_ids,
#    1290     past_key_values=past_key_values,
#    1291     inputs_embeds=inputs_embeds,
#    1292     use_cache=use_cache,
#    1293     output_attentions=output_attentions,
#    1294     output_hidden_states=output_hidden_states,
#    1295     return_dict=return_dict,
#    1296 )
#    1298 hidden_states = outputs[0]
#    1299 logits = self.lm_head(hidden_states)
#
# File ~/miniconda/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/bbd531db4632bb631b0c44d98172894a0c594dd0/modeling_phi3.py:1164, in Phi3Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1154     layer_outputs = self._gradient_checkpointing_func(
#    1155         decoder_layer.__call__,
#    1156         hidden_states,
#    (...)
#    1161         use_cache,
#    1162     )
#    1163 else:
# -> 1164     layer_outputs = decoder_layer(
#    1165         hidden_states,
#    1166         attention_mask=attention_mask,
#    1167         position_ids=position_ids,
#    1168         past_key_value=past_key_values,
#    1169         output_attentions=output_attentions,
#    1170         use_cache=use_cache,
#    1171     )
#    1173 hidden_states = layer_outputs[0]
#    1175 if use_cache:
#
# File ~/miniconda/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/bbd531db4632bb631b0c44d98172894a0c594dd0/modeling_phi3.py:885, in Phi3DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     882 hidden_states = self.input_layernorm(hidden_states)
#     884 # Self Attention
# --> 885 attn_outputs, self_attn_weights, present_key_value = self.self_attn(
#     886     hidden_states=hidden_states,
#     887     attention_mask=attention_mask,
#     888     position_ids=position_ids,
#     889     past_key_value=past_key_value,
#     890     output_attentions=output_attentions,
#     891     use_cache=use_cache,
#     892 )
#     894 hidden_states = residual + self.resid_attn_dropout(attn_outputs)
#     896 residual = hidden_states
#
# File ~/miniconda/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/bbd531db4632bb631b0c44d98172894a0c594dd0/modeling_phi3.py:389, in Phi3Attention.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache)
#     386 key_states = repeat_kv(key_states, self.num_key_value_groups)
#     387 value_states = repeat_kv(value_states, self.num_key_value_groups)
# --> 389 attn_weights = torch.matmul(query_states, key_states.transpose(2, 3)) / math.sqrt(self.head_dim)
#     391 if attn_weights.size() != (bsz, self.num_heads, q_len, kv_seq_len):
#     392     raise ValueError(
#     393         f"Attention weights should be of size {(bsz, self.num_heads, q_len, kv_seq_len)}, but is"
#     394         f" {attn_weights.size()}"
#     395     )
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 12.42 GiB. GPU
